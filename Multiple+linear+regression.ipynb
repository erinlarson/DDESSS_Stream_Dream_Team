# %% [markdown]
# # Multiple linear regression

# %%
setwd('/Users/maullabmacbookpro/DDESSS_Stream_Dream_Team')
data<-read.csv('WorkingDataSet.csv')
head(data)
# Out:
#   X ResultMeasure2 STRAHLER2 DrainageAreaMeasure_MeasureValue HUCEightDigitCode
# 1 1 0              2.4       195                              15060103
# 2 2 0              2.4       195                              15060103
# 3 3 0              2.4       195                              15060103
# 4 4 0              2.4       195                              15060103
# 5 5 0              2.4       195                              15060103
# 6 6 0              2.4       195                              15060103
#   date                 ResultSampleFractionText PFOR2  PWETL2 PURB2 PAGT2
# 1 2001-02-07T00:00:00Z Total                    73.918 0.01   0.132 0.076
# 2 2001-04-19T00:00:00Z Total                    73.918 0.01   0.132 0.076
# 3 2001-09-04T00:00:00Z Total                    73.918 0.01   0.132 0.076
# 4 2001-12-20T00:00:00Z Total                    73.918 0.01   0.132 0.076
# 5 2002-06-11T00:00:00Z Total                    73.918 0.01   0.132 0.076
# ...

# %%
TDP<-subset(data, ResultSampleFractionText=="Dissolved")
Total<-subset(data, ResultSampleFractionText=="Total")

# %% [markdown]
# do multiple linear regression: fit <- lm(y ~ x1 + x2 + x3, data=mydata)
# summary(fit) # show results

# %%
total.fit<-lm(ResultMeasure2~ PFOR2+PWETL2+PURB2+PAGT2, data=Total)
summary(total.fit)
# Out:
# Call:
# lm(formula = ResultMeasure2 ~ PFOR2 + PWETL2 + PURB2 + PAGT2,
#     data = Total)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.17951 -0.04117 -0.02674  0.00683  2.68040
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.449e-02  5.857e-03   2.473   0.0134 *
# PFOR2        7.202e-04  9.854e-05   7.309 3.29e-13 ***
# PWETL2      -4.043e-03  1.230e-02  -0.329   0.7424
# PURB2        2.453e-01  3.140e-02   7.810 7.37e-15 ***
# PAGT2       -6.001e-03  6.145e-03  -0.977   0.3289
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.137 on 3688 degrees of freedom
# Multiple R-squared:  0.03005,	Adjusted R-squared:  0.029
# F-statistic: 28.56 on 4 and 3688 DF,  p-value: < 2.2e-16

# %%
step(total.fit)
# Out:
# Start:  AIC=-14675.33
# ResultMeasure2 ~ PFOR2 + PWETL2 + PURB2 + PAGT2
#
#          Df Sum of Sq    RSS    AIC
# - PWETL2  1   0.00203 69.248 -14677
# - PAGT2   1   0.01791 69.264 -14676
# <none>                69.246 -14675
# - PFOR2   1   1.00298 70.249 -14624
# - PURB2   1   1.14540 70.391 -14617
#
# Step:  AIC=-14677.22
# ResultMeasure2 ~ PFOR2 + PURB2 + PAGT2
#
#         Df Sum of Sq    RSS    AIC
# - PAGT2  1   0.02189 69.270 -14678
# <none>               69.248 -14677
# - PFOR2  1   1.06794 70.316 -14623
# - PURB2  1   1.14713 70.395 -14618
#
# Step:  AIC=-14678.06
# ResultMeasure2 ~ PFOR2 + PURB2
#
#         Df Sum of Sq    RSS    AIC
# <none>               69.270 -14678
# - PFOR2  1    1.0525 70.322 -14624
# - PURB2  1    1.1425 70.412 -14620
# Call:
# lm(formula = ResultMeasure2 ~ PFOR2 + PURB2, data = Total)
#
# Coefficients:
# (Intercept)        PFOR2        PURB2
#   0.0136481    0.0007042    0.2449105

# %%
total.fit<-lm(ResultMeasure2~ PFOR2+PURB2, data=Total)
summary(total.fit)
# Out:
# Call:
# lm(formula = ResultMeasure2 ~ PFOR2 + PURB2, data = Total)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.17833 -0.04110 -0.02710  0.00664  2.68197
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.365e-02  5.740e-03   2.378   0.0175 *
# PFOR2       7.042e-04  9.405e-05   7.488 8.72e-14 ***
# PURB2       2.449e-01  3.139e-02   7.802 7.90e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.137 on 3690 degrees of freedom
# Multiple R-squared:  0.02972,	Adjusted R-squared:  0.02919
# F-statistic:  56.5 on 2 and 3690 DF,  p-value: < 2.2e-16

# %%
TDP.fit<-lm(ResultMeasure2~ PFOR2+PWETL2+PURB2+PAGT2, data=TDP)
summary(TDP.fit)
# Out:
# Call:
# lm(formula = ResultMeasure2 ~ PFOR2 + PWETL2 + PURB2 + PAGT2,
#     data = TDP)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.15288 -0.01990 -0.01121  0.00510  1.29625
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0061425  0.0064292   0.955    0.340
# PFOR2        0.0005223  0.0001280   4.079 4.80e-05 ***
# PWETL2       0.0567522  0.0455163   1.247    0.213
# PURB2        0.2335494  0.0300413   7.774 1.50e-14 ***
# PAGT2       -0.0292274  0.0069514  -4.205 2.79e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05926 on 1344 degrees of freedom
# Multiple R-squared:  0.04976,	Adjusted R-squared:  0.04693
# F-statistic: 17.59 on 4 and 1344 DF,  p-value: 4.379e-14

# %%
step(TDP.fit)
# Out:
# Start:  AIC=-7619.28
# ResultMeasure2 ~ PFOR2 + PWETL2 + PURB2 + PAGT2
#
#          Df Sum of Sq    RSS     AIC
# - PWETL2  1  0.005459 4.7245 -7619.7
# <none>                4.7191 -7619.3
# - PFOR2   1  0.058407 4.7775 -7604.7
# - PAGT2   1  0.062071 4.7811 -7603.7
# - PURB2   1  0.212215 4.9313 -7561.9
#
# Step:  AIC=-7619.72
# ResultMeasure2 ~ PFOR2 + PURB2 + PAGT2
#
#         Df Sum of Sq    RSS     AIC
# <none>               4.7245 -7619.7
# - PFOR2  1  0.060194 4.7847 -7604.6
# - PAGT2  1  0.087201 4.8117 -7597.1
# - PURB2  1  0.226832 4.9513 -7558.5
# Call:
# lm(formula = ResultMeasure2 ~ PFOR2 + PURB2 + PAGT2, data = TDP)
#
# Coefficients:
# (Intercept)        PFOR2        PURB2        PAGT2
#   0.0074792    0.0005296    0.2389427   -0.0323366

# %%
TDP.fit<-lm(ResultMeasure2~ PFOR2+PURB2+PAGT2, data=TDP)
summary(TDP.fit)
# Out:
# Call:
# lm(formula = ResultMeasure2 ~ PFOR2 + PURB2 + PAGT2, data = TDP)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.15552 -0.02080 -0.01180  0.00718  1.29438
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0074792  0.0063405   1.180    0.238
# PFOR2        0.0005296  0.0001279   4.140 3.70e-05 ***
# PURB2        0.2389427  0.0297344   8.036 2.02e-15 ***
# PAGT2       -0.0323366  0.0064901  -4.982 7.09e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05927 on 1345 degrees of freedom
# Multiple R-squared:  0.04866,	Adjusted R-squared:  0.04654
# F-statistic: 22.93 on 3 and 1345 DF,  p-value: 1.767e-14

# %%
plot(TDP$PFOR2, TDP$ResultMeasure2)
# Out:
# plot without title

# %%
plot(TDP$PURB2, TDP$ResultMeasure2)
# Out:
# plot without title

# %%
plot(Total$PFOR2, Total$ResultMeasure2)
# Out:
# plot without title
