# %%
setwd("/Users/Naila/DDESSS_Stream_Dream_Team")

# %%
landuse.p = read.csv("LandUsetoPhosphorusMerge1_SQL-csv.csv")

# %%
summary(landuse.p)
# Out:
#   ActivityStartDate       mo              day
#  2002-07-17:  40    Min.   : 1.000   Min.   : 1.00
#  2002-07-18:  20    1st Qu.: 4.000   1st Qu.:10.00
#  2000-03-29:  19    Median : 7.000   Median :17.00
#  2000-07-19:  19    Mean   : 6.523   Mean   :16.56
#  2000-05-18:  18    3rd Qu.: 9.000   3rd Qu.:22.00
#  2001-07-17:  18    Max.   :12.000   Max.   :31.00
#  (Other)   :6048
#                    date      MonitoringLocationIdentifier
#  2002-07-17T00:00:00Z:  40   USGS-09498500: 630
#  2002-07-18T00:00:00Z:  20   USGS-09041400: 250
#  2000-03-29T00:00:00Z:  19   USGS-09041090: 230
#  2000-07-19T00:00:00Z:  19   USGS-09025010: 228
#  2000-05-18T00:00:00Z:  18   USGS-09027100: 228
#  2001-07-17T00:00:00Z:  18   USGS-09023750: 227
#  (Other)             :6048   (Other)      :4389
#            HydrologicCondition       HydrologicEvent
#  Stable, normal stage:6182     Routine sample:6182
#
#
#
#
#
#
#  ResultDetectionConditionText  CharacteristicName ResultSampleFractionText
# ...

# %%
library(ggplot2)
library(lattice)
library(RColorBrewer)

# %%
display.brewer.all()
# Out:
# plot without title

# %%
total.P.plot<-plot(ResultMeasureValue~date, data=landuse.p, type="p", xlab="Date", ylab="Phosphorus mg/L", main= "Time Series")
total.P.plot
# Out:
# NULL
# Plot with title “Time Series”

# %%
head(landuse.p)
# Out:
#   ActivityStartDate mo day date                 MonitoringLocationIdentifier
# 1 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 2 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 3 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 4 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 5 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 6 2001-04-19        4  19  2001-04-19T00:00:00Z USGS-09498400
#   HydrologicCondition  HydrologicEvent ResultDetectionConditionText
# 1 Stable, normal stage Routine sample  Not Detected
# 2 Stable, normal stage Routine sample  Not Detected
# 3 Stable, normal stage Routine sample  Not Detected
# 4 Stable, normal stage Routine sample  Not Detected
# 5 Stable, normal stage Routine sample  Not Detected
# 6 Stable, normal stage Routine sample  Not Detected
#   CharacteristicName ResultSampleFractionText ⋯ YEAR PFOR  PWETL PURB PAGT
# ...
