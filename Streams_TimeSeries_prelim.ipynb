# %%
setwd("/Users/erinlarson/Dropbox/Documents/GIT/DDESSS_Stream_Dream_Team")

# %%
landuse.p = read.csv("avg_landuse_to_P_join.csv")

# %%
summary(landuse.p)
# Out:
#  ActivityStartDate       mo              day                          date
#  7/17/01:  18      Min.   : 1.000   Min.   : 1.00   2001-07-17T00:00:00Z:  18
#  4/17/07:  17      1st Qu.: 4.000   1st Qu.:10.00   2007-04-17T00:00:00Z:  17
#  6/17/08:  17      Median : 7.000   Median :17.00   2008-06-17T00:00:00Z:  17
#  3/29/00:  15      Mean   : 6.534   Mean   :16.54   2000-03-29T00:00:00Z:  15
#  6/13/01:  15      3rd Qu.: 9.000   3rd Qu.:22.00   2000-07-19T00:00:00Z:  15
#  7/19/00:  15      Max.   :12.000   Max.   :31.00   2001-06-13T00:00:00Z:  15
#  (Other):4955                                       (Other)             :4955
#  MonitoringLocationIdentifier           HydrologicCondition
#  USGS-09041400: 250           Stable, normal stage:5052
#  USGS-09041090: 230
#  USGS-09025010: 228
#  USGS-09027100: 228
#  USGS-09023750: 227
#  USGS-09013500: 199
#  (Other)      :3690
#        HydrologicEvent ResultDetectionConditionText  CharacteristicName
# ...

# %%
library(ggplot2)
library(lattice)
library(RColorBrewer)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 3.3.2”

# %%
display.brewer.all()
# Out:
# plot without title

# %%
total.P.plot<-plot(ResultMeasureValue~DrainageAreaMeasure_MeasureValue, data=subset(landuse.p, ResultSampleFractionText=="Total"), type="p", xlab="Drainage Area (sq. miles)", ylab="Total Phosphorus mg/L")
total.P.plot
# Out:
# NULL
# plot without title

# %%
head(landuse.p)
# Out:
#   ActivityStartDate mo day date                 MonitoringLocationIdentifier
# 1 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 2 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 3 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 4 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 5 2001-02-07        2   7  2001-02-07T00:00:00Z USGS-09498400
# 6 2001-04-19        4  19  2001-04-19T00:00:00Z USGS-09498400
#   HydrologicCondition  HydrologicEvent ResultDetectionConditionText
# 1 Stable, normal stage Routine sample  Not Detected
# 2 Stable, normal stage Routine sample  Not Detected
# 3 Stable, normal stage Routine sample  Not Detected
# 4 Stable, normal stage Routine sample  Not Detected
# 5 Stable, normal stage Routine sample  Not Detected
# 6 Stable, normal stage Routine sample  Not Detected
#   CharacteristicName ResultSampleFractionText ⋯ YEAR PFOR  PWETL PURB PAGT
# ...
